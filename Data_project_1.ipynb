# %%
import mysql.connector
import pandas as pd

# %%
def create_database():
    #connect to default database
    conn=mysql.connector.connect(host='localhost',
                             user='root',
                             password="*****8***",
                            database='new_pythondatabase')
    cur=conn.cursor()
    #create target database
    cur.execute("drop database if exists foodp")
    cur.execute("create database foodp")
    #close connection to default database
    conn.close()
    #connect to target database
    conn=mysql.connector.connect(host='localhost',
                             user='root',
                             password="Sid@9040634811",
                            database='foodp')
    cur=conn.cursor()
    return conn,cur

# %%
#def drop_tables(cur,conn):

# %%
FastFood=pd.read_csv("FastFoodRestaurants.csv")

# %%
FastFood
# Out:
#                     address                    city country  \
# 0               324 Main St                 Massena      US
# 1           530 Clinton Ave  Washington Court House      US
# 2      408 Market Square Dr               Maysville      US
# 3     6098 State Highway 37                 Massena      US
# 4           139 Columbus Rd                  Athens      US
# ...                     ...                     ...     ...
# 9995  3013 Peach Orchard Rd                 Augusta      US
# 9996      678 Northwest Hwy                    Cary      US
# 9997           1708 Main St                Longmont      US
# 9998      67740 Highway 111          Cathedral City      US
# 9999    5701 E La Palma Ave                 Anaheim      US
#
#                                                    keys   latitude  \
# 0                   us/ny/massena/324mainst/-1161002137  44.921300
# 1     us/oh/washingtoncourthouse/530clintonave/-7914...  39.532550
# ...

# %%
Fast_Food=FastFood[['name','country','city','province','postalCode','address']]

# %%
Fast_Food.head()
# Out:
#                name country                    city province postalCode  \
# 0        McDonald's      US                 Massena       NY      13662
# 1           Wendy's      US  Washington Court House       OH      43160
# 2  Frisch's Big Boy      US               Maysville       KY      41056
# 3        McDonald's      US                 Massena       NY      13662
# 4   OMG! Rotisserie      US                  Athens       OH      45701
#
#                  address
# 0            324 Main St
# 1        530 Clinton Ave
# 2   408 Market Square Dr
# 3  6098 State Highway 37
# 4        139 Columbus Rd

# %%
Datafin=pd.read_csv('Datafiniti_Fast_Food_Restaurants_Jun19.csv')

# %%
Datafin
# Out:
#                         id             dateAdded           dateUpdated  \
# 0     AWrSh_KgsVYjT2BJAzaH  2019-05-19T23:58:05Z  2019-05-19T23:58:05Z
# 1     AWEKlA-LIxWefVJwxG9B  2018-01-18T18:30:23Z  2019-05-19T23:45:05Z
# 2     AWrSfAcYsVYjT2BJAzPt  2019-05-19T23:45:04Z  2019-05-19T23:45:04Z
# 3     AWrSa3NAQTFama1Xpkbz  2019-05-19T23:26:58Z  2019-05-19T23:26:58Z
# 4     AWrSaVGzZ4Yw-wtdgcaB  2019-05-19T23:24:38Z  2019-05-19T23:24:38Z
# ...                    ...                   ...                   ...
# 9995  AVwd7U0T_7pvs4fz-fS_  2016-05-31T13:33:45Z  2018-12-03T09:04:19Z
# 9996  AV1XW1fF3D1zeR_xFKHL  2017-07-18T20:19:50Z  2018-12-02T00:08:36Z
# 9997  AV5UVbkiRxPSIh2RiQxV  2017-09-05T23:05:50Z  2018-12-01T07:38:03Z
# 9998  AVwc9BxYByjofQCxj_GW  2016-03-31T02:43:12Z  2018-12-01T07:35:22Z
# 9999  AVzA_GF53D1zeR_xBDVW  2017-06-19T15:33:04Z  2018-12-01T00:03:40Z
#
#                           address  \
# 0                2555 11th Avenue
# 1           2513 Highway 6 And 50
# ...

# %%
jun19=Datafin[['name','country','city','address','postalCode','id']]

# %%
jun19=jun19.drop(['id'],axis=1)

# %%
jun19.head()
# Out:
#                      name country            city                address  \
# 0              Carl's Jr.      US         Greeley       2555 11th Avenue
# 1                Del Taco      US  Grand Junction  2513 Highway 6 And 50
# 2              Which Wich      US  Grand Junction    1125 Patterson Road
# 3  Chipotle Mexican Grill      US          Aurora    3455 N Salida Court
# 4               Taco Bell      US          Denver   5225 E Colfax Avenue
#
#   postalCode
# 0      80631
# 1      81505
# 2      81506
# 3      80011
# 4      80220

# %%
conn,cur=create_database()

# %%
foodtable_create="create table food(name longtext,country longtext,city longtext,province longtext,postalCode longtext,address longtext);"

# %%
cur.execute(foodtable_create)
conn.commit()

# %%
jun19_table="create table jun19(name longtext,country longtext,city longtext,address longtext,postalCode longtext);"

# %%
cur.execute(jun19_table)
conn.commit()

# %%
foodtable_create_insert="insert into food values(%s,%s,%s,%s,%s,%s)"

# %%
for i, row in Fast_Food.iterrows():
    cur.execute(foodtable_create_insert,list(row))
   # print(list(row))

# %%
conn.commit()

# %%
jun19_table_insert="insert into jun19 values(%s,%s,%s,%s,%s)"
for i, row in jun19.iterrows():
    cur.execute(jun19_table_insert,list(row))

# %%
conn.commit()

# %%
conn.close()
